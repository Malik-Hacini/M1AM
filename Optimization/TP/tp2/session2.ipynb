# %% [markdown]
# ## Practical session 2: gradient descent and line-search
#
# In today's session, we will implement the gradient descent algorithm and use it to solve problems of the form
# $$
# \min_{x \in \mathbb{R}^d} f(x).
# $$
# The gradient descent algorithm is a first-order algorithm, meaning that it only requires a first-order oracle of $f$. The performance of the gradient descent algorithm depends on only one parameter, called the step size. This step size can be fixed in advance if we have some information about the regularity of $f$, but it can also be adapted along the iterations if not enough information are available. In this practical session, you will implement the gradient descent algorithm with fixed step size as well as some strategies to iteratively adapt the step sizes.

# %% [markdown]
# ### Gradient descent with fixed step size
#
# Starting from an initial point $x_0 \in \mathbb{R}^d$, the gradient descent algorithm with fixed step size $\tau > 0$ generates a sequence $\{x_k\}$ such that for any $k \in \mathbb{N}$,
# $$
# x_{k+1} = x_k - \tau \nabla f(x_k).
# $$
# The stopping criterion for the gradient descent algorithm will generally be an approximate first-order stationarity condition of the form $\| \nabla f(x)\| \leq \epsilon$ for some small $\epsilon > 0$. A maximum number of iterations can also be enforced.

# %% [markdown]
# > Complete the function `GD` in the file `algorithms.py`.

# %%
from utils import *
from algorithms import *

# %% [markdown]
# You will now test the gradient descent algorithm on the objective function $f_1$.

# %%
import problem1 as pb1

# %% [markdown]
# > Plot the trajectory of the iterates generated by the gradient descent algorithm implemented in the function `GD` as well as the objective function and gradient norm values achieved by the iterates using the functions `level_points_plot` and `plot_obj_normGrad` from the file `utils.py`. Use $x_0 = (4,4)$ with a precision parameter $\texttt{prec}=10^{-5}$ and a maximum number of iteration $\texttt{iterMax} = 10^3$. Try the values $\tau \in \{0.1, 0.3, 0.5\}$.

# %%
x_init = np.array([4.0, 4.0])
prec = 1e-5
iterMax = 1000
tau = 0.1
x_star, x_tab = GD(pb1.f, pb1.grad_f, x_init, tau, iterMax, prec)
level_points_plot(pb1.f, x_tab, pb1.lb, pb1.ub, pb1.nb_points, pb1.levels, r"GD on $f_1$ with $\tau=0.1$")
plot_obj_normGrad(x_tab, pb1.f, pb1.grad_f, r"GD on $f_1$ with $\tau=0.1$")
# Out:
# ------------------------------------
#  GD with constant step size
# ------------------------------------
# START
# FINISHED -- 139 iterations -- 0.003596s -- final value: 0.000000 -- final gradient norm: 0.000193

# %%
x_init = np.array([4.0, 4.0])
prec = 1e-5
iterMax = 1000
tau = 0.3
x_star, x_tab = GD(pb1.f, pb1.grad_f, x_init, tau, iterMax, prec)
level_points_plot(pb1.f, x_tab, pb1.lb, pb1.ub, pb1.nb_points, pb1.levels, r"GD on $f_1$ with $\tau=0.3$")
plot_obj_normGrad(x_tab, pb1.f, pb1.grad_f, r"GD on $f_1$ with $\tau=0.3$")
# Out:
# ------------------------------------
#  GD with constant step size
# ------------------------------------
# START
# FINISHED -- 44 iterations -- 0.001841s -- final value: 0.000000 -- final gradient norm: 0.000153

# %%
x_init = np.array([4.0, 4.0])
prec = 1e-5
iterMax = 1000
tau = 0.5
x_star, x_tab = GD(pb1.f, pb1.grad_f, x_init, tau, iterMax, prec)
level_points_plot(pb1.f, x_tab, pb1.lb, pb1.ub, pb1.nb_points, pb1.levels, r"GD on $f_1$ with $\tau=0.5$")
plot_obj_normGrad(x_tab, pb1.f, pb1.grad_f, r"GD on $f_1$ with $\tau=0.5$")
# Out:
# ------------------------------------
#  GD with constant step size
# ------------------------------------
# START
# FINISHED -- 310 iterations -- 0.004970s -- final value: 0.000000 -- final gradient norm: 0.000207

# %% [markdown]
# > What is the "best" choice of step size among the three step sizes you tried?

# %% [markdown]
# > What happens if you try to larger values of $\tau$ (e.g., $\tau = 0.51$)?

# %%
x_init = np.array([4.0, 4.0])
prec = 1e-5
iterMax = 1000
tau = 0.51
x_star, x_tab = GD(pb1.f, pb1.grad_f, x_init, tau, iterMax, prec)
level_points_plot(pb1.f, x_tab, pb1.lb, pb1.ub, pb1.nb_points, pb1.levels, r"GD on $f_1$ with $\tau=0.51$")
plot_obj_normGrad(x_tab, pb1.f, pb1.grad_f, r"GD on $f_1$ with $\tau=0.51$")
print('tau = 0.51 is above the stable range here, so the iterates diverge.')
# Out:
# ------------------------------------
#  GD with constant step size
# ------------------------------------
# START
# FINISHED -- 999 iterations -- 0.036541s -- final value: 15842.421466 -- final gradient norm: 352.743524
# tau = 0.51 is above the stable range here, so the iterates diverge.

# %% [markdown]
# ### Line-search methods
#
# As we saw in the previous example, gradient descent with fixed step size is very easy to implement and can convergence very fast on "easy" problems if the step size is well chosen. You will see in the lectures that if $\nabla f$ is $L$-Lipschitz, choosing $\tau \leq 1/L$ ensures that the iterates $\{ x_k \}$ generated by GD yield a non-increasing sequence $\{ f(x_k) \}$ and that $\nabla f(x_k) \rightarrow 0$ (these results can be strengthened under additional hypotheses on $f$).
#
# An alternative to knowing $L$ is to adapt the step size at every iteration. In this context, we will introduce line-search methods, which allow to achieve this goal.
#
# How do line-search methods work? At iteration $k \in \mathbb{N}$, the GD algorithm updates the iterate $x_k$ using the update
# $$
# x_{k+1} = x_k - \tau \nabla f(x_k)
# $$
# for some $\tau > 0$. Then, a natural idea is to consider the function $\phi_k : (0,\infty) \rightarrow \mathbb{R}$ defined for any $\tau > 0$ by
# $$
# \phi_k(\tau) = f(x_k - \tau \nabla f(x_k))
# $$
# and minimize it. Notice that $\phi_k(0) = f(x_k)$. Minimizing $\phi_k$ is generally too costly, so line-search methods only aim at finding $\tau > 0$ such that
# $$
# f(x_k - \tau \nabla f(x_k)) \leq f(x_k) - c \tau \| \nabla f(x_k) \|^2
# $$
# is satisfied for some value $c \in (0,1)$. This condition is called the Armijo condition and requires the line-search to achieve a sufficient decrease in the function $f$ (controlled by the constant $c$) at every iteration.

# %% [markdown]
# The backtracking line-search (also called Armijo line-search) is a straightforward line-search method that allows to find step sizes $\tau$ satisfying the Armijo condition. Backtracking works as follows:
# - choose parameters $\tau_0 > 0$, $c \in (0,1)$, and $\rho \in (0,1)$ and set $\tau \leftarrow \tau_0$.
# - while $f(x_k - \tau \nabla f(x_k)) > f(x_k) + c \tau \| \nabla f(x_k) \|^2$, update $\tau \leftarrow \rho \tau$.
# - once the loop stops, use the final value of $\tau$ as the step size in the gradient descent algorithm.

# %% [markdown]
# > Implement the gradient descent algorithm with backtracking line-search in the `algorithms.py` file.

# %% [markdown]
# > Run the gradient descent algorithm with backtracking line-search on the function $f_1$ with $\rho = 0.5$, $c=0.01$, and $\tau_0 \in \{0.1, 1.0, 10.0\}$. What do you observe and how do you interpret these results?

# %%
x_init = np.array([4.0, 4.0])
prec = 1e-5
iterMax = 1000
x_star, x_tab = GD_backtracking(pb1.f, pb1.grad_f, x_init, 0.1, 0.5, 0.01, iterMax, prec)
level_points_plot(pb1.f, x_tab, pb1.lb, pb1.ub, pb1.nb_points, pb1.levels, r"Backtracking GD on $f_1$ with $\tau_0=0.1$")
plot_obj_normGrad(x_tab, pb1.f, pb1.grad_f, r"Backtracking GD on $f_1$ with $\tau_0=0.1$")
# Out:
# ------------------------------------
#  GD with backtracking line search
# ------------------------------------
# START
# FINISHED -- 139 iterations -- 0.009408s -- final value: 0.000000 -- final gradient norm: 0.000193

# %%
x_init = np.array([4.0, 4.0])
prec = 1e-5
iterMax = 1000
x_star, x_tab = GD_backtracking(pb1.f, pb1.grad_f, x_init, 1.0, 0.5, 0.01, iterMax, prec)
level_points_plot(pb1.f, x_tab, pb1.lb, pb1.ub, pb1.nb_points, pb1.levels, r"Backtracking GD on $f_1$ with $\tau_0=1$")
plot_obj_normGrad(x_tab, pb1.f, pb1.grad_f, r"Backtracking GD on $f_1$ with $\tau_0=1$")
# Out:
# ------------------------------------
#  GD with backtracking line search
# ------------------------------------
# START
# FINISHED -- 310 iterations -- 0.023261s -- final value: 0.000000 -- final gradient norm: 0.000207

# %%
x_init = np.array([4.0, 4.0])
prec = 1e-5
iterMax = 1000
x_star, x_tab = GD_backtracking(pb1.f, pb1.grad_f, x_init, 10.0, 0.5, 0.01, iterMax, prec)
level_points_plot(pb1.f, x_tab, pb1.lb, pb1.ub, pb1.nb_points, pb1.levels, r"Backtracking GD on $f_1$ with $\tau_0=10$")
plot_obj_normGrad(x_tab, pb1.f, pb1.grad_f, r"Backtracking GD on $f_1$ with $\tau_0=10$")
# Out:
# ------------------------------------
#  GD with backtracking line search
# ------------------------------------
# START
# FINISHED -- 20 iterations -- 0.002396s -- final value: 0.000000 -- final gradient norm: 0.000116

# %% [markdown]
# ### To go further: Exact line-search for quadratic problems
#
# In general, minimizing the function $\phi_k : \tau \longmapsto f(x_k - \tau \nabla f(x_k))$ is not worth the effort, so line-search methods only aim at finding a step size $\tau$ that satisfies a sufficient decrease condition. However, if $f$ is quadratic, that is
# $$
# f(x) = \frac{1}{2} x^\top A x + b^\top x + c
# $$
# with $A \succcurlyeq 0$ and symmetric, then the minimizer of $\phi_k$ can be written in closed-form.

# %% [markdown]
# > Solve $\phi_k^\prime(\tau) = 0$ in $\tau$ (use that $\nabla f(x) = Ax + b$ at some point). The solution is the optimal step size for the iteration $k$.

# %% [markdown]
# > Implement the gradient descent algorithm with exact line-search for quadratic functions and run it on $f_1$ (you can use that $A$ is the Hessian of $A$).

# %%
x_init = np.array([4.0, 4.0])
prec = 1e-5
iterMax = 1000
A = pb1.hessian_f(np.zeros(2))
print(r'$\tau_k = \|g_k\|^2 / \langle g_k, A g_k \rangle$')
x_star, x_tab = GD_exact(A, pb1.f, pb1.grad_f, x_init, iterMax, prec)
level_points_plot(pb1.f, x_tab, pb1.lb, pb1.ub, pb1.nb_points, pb1.levels, r"Exact line-search GD on $f_1$")
plot_obj_normGrad(x_tab, pb1.f, pb1.grad_f, r"Exact line-search GD on $f_1$")
# Out:
# $\tau_k = \|g_k\|^2 / \langle g_k, A g_k \rangle$
# ------------------------------------
#  GD with exact line search
# ------------------------------------
# START
# FINISHED -- 5 iterations -- 0.000317s -- final value: 0.000000 -- final gradient norm: 0.000004

# %% [markdown]
# ### To go further: A more challenging quadratic problem
#
# The objective function $f_1$ is a quadratic function which is relatively simple to minimize: its Hessian matrix has a low condition number (ratio of the largest and smallest eigenvalues, this quantity controls the "elongation" of the level sets) and the search space is low-dimensional. You are now going to consider the objective function $f_3$, which is a quadratic function in dimension $d=10^3$ whose Hessian has a condition number $\kappa = 10^6$ (note that these numbers are still small compared to some large-scale optimization problems seen in some applications such as machine learning, image processing, or meteorology, to name a few).

# %%
import problem3 as pb3

# %% [markdown]
# > Try running the gradient descent algorithm with fixed step size $\tau \in \{ 10^{-7}, 10^{-6}, 10^{-5} \}$, the gradient descent algorithm with backtracking line search, and the gradient descent algorithm with perfect line search to minimize $f_3$.

# %%
x_init = np.zeros(pb3.d)
prec = 1e-5
iterMax = 500
x_star, x_tab = GD(pb3.f, pb3.grad_f, x_init, 1e-7, iterMax, prec)
plot_obj_normGrad(x_tab, pb3.f, pb3.grad_f, r"GD on $f_3$ with $\tau=10^{-7}$")
# Out:
# ------------------------------------
#  GD with constant step size
# ------------------------------------
# START
# FINISHED -- 499 iterations -- 2.628807s -- final value: 12894499.748973 -- final gradient norm: 518449.678554

# %%
x_init = np.zeros(pb3.d)
prec = 1e-5
iterMax = 500
x_star, x_tab = GD(pb3.f, pb3.grad_f, x_init, 1e-6, iterMax, prec)
plot_obj_normGrad(x_tab, pb3.f, pb3.grad_f, r"GD on $f_3$ with $\tau=10^{-6}$")
# Out:
# ------------------------------------
#  GD with constant step size
# ------------------------------------
# START
# FINISHED -- 499 iterations -- 3.068445s -- final value: 1199493.283676 -- final gradient norm: 48558.537675

# %%
x_init = np.zeros(pb3.d)
prec = 1e-5
iterMax = 500
x_star, x_tab = GD(pb3.f, pb3.grad_f, x_init, 1e-5, iterMax, prec)
plot_obj_normGrad(x_tab, pb3.f, pb3.grad_f, r"GD on $f_3$ with $\tau=10^{-5}$")
# Out:
# ------------------------------------
#  GD with constant step size
# ------------------------------------
# START
# /home/tag/Desktop/M1AM/Optimization/TP/tp2/algorithms.py:19: RuntimeWarning: invalid value encountered in subtract
#   x = x - tau*g
# /home/tag/Desktop/M1AM/Optimization/TP/tp2/problem3.py:32: RuntimeWarning: invalid value encountered in matmul
#   return A@x + b
# FINISHED -- 499 iterations -- 1.320441s -- final value: nan -- final gradient norm: nan
# /home/tag/Desktop/M1AM/Optimization/TP/tp2/problem3.py:28: RuntimeWarning: invalid value encountered in scalar add
#   return 0.5*np.inner(x, A@x) + np.inner(b,x) + c
# /home/tag/Desktop/M1AM/Optimization/TP/tp2/problem3.py:28: RuntimeWarning: invalid value encountered in matmul
#   return 0.5*np.inner(x, A@x) + np.inner(b,x) + c
# /home/tag/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/scale.py:270: RuntimeWarning: overflow encountered in power
#   return np.power(self.base, values)

# %%
x_init = np.zeros(pb3.d)
prec = 1e-5
iterMax = 500
x_star, x_tab = GD_backtracking(pb3.f, pb3.grad_f, x_init, 1.0, 0.5, 0.01, iterMax, prec)
plot_obj_normGrad(x_tab, pb3.f, pb3.grad_f, r"Backtracking GD on $f_3$")
# Out:
# ------------------------------------
#  GD with backtracking line search
# ------------------------------------
# START
# FINISHED -- 499 iterations -- 28.693877s -- final value: 596307.725737 -- final gradient norm: 42425.330815

# %%
x_init = np.zeros(pb3.d)
prec = 1e-5
iterMax = 500
x_star, x_tab = GD_exact(pb3.hessian_f(np.zeros(pb3.d)), pb3.f, pb3.grad_f, x_init, iterMax, prec)
plot_obj_normGrad(x_tab, pb3.f, pb3.grad_f, r"Exact line-search GD on $f_3$")
# Out:
# ------------------------------------
#  GD with exact line search
# ------------------------------------
# START
# FINISHED -- 499 iterations -- 1.518640s -- final value: 613489.409532 -- final gradient norm: 35198.568567

# %% [markdown]
# ### To go further: Minimizing the Rosenbrock function
#
# Only quadratic objective functions have been considered so far. Let us now try to use gradient descent algorithms to minimize the Rosenbrock function $f_2$.

# %%
import problem2 as pb2

# %% [markdown]
# > Find a step size $\tau > 0$ such that the gradient descent algorithm with fixed step size generates a decreasing sequence $\{ f(x_k)\}$ of function values when initialized at $(0,0)$.

# %%
tau = 5e-3
x_init = np.array([0.0, 0.0])
x_star, x_tab = GD(pb2.f, pb2.grad_f, x_init, tau, 1000, 1e-5)
plot_obj_normGrad(x_tab, pb2.f, pb2.grad_f, r"GD on Rosenbrock with $x_0=(0,0)$ and $\tau=5\times 10^{-3}$")
print('A decreasing sequence is obtained for tau = 5e-3.')
# Out:
# ------------------------------------
#  GD with constant step size
# ------------------------------------
# START
# FINISHED -- 999 iterations -- 0.006750s -- final value: 0.453567 -- final gradient norm: 13.206460
# A decreasing sequence is obtained for tau = 5e-3.

# %% [markdown]
# > Does this step size still allows to achieve decrease when starting from outside of the "valley" of $f_2$, for instance if $x_0 = (-4,-4)$?

# %%
tau = 5e-3
x_init = np.array([-4.0, -4.0])
x_star, x_tab = GD(pb2.f, pb2.grad_f, x_init, tau, 1000, 1e-5)
plot_obj_normGrad(x_tab, pb2.f, pb2.grad_f, r"GD on Rosenbrock with $x_0=(-4,-4)$ and $\tau=5\times 10^{-3}$")
print('From (-4,-4), the same step size diverges.')
# Out:
# ------------------------------------
#  GD with constant step size
# ------------------------------------
# START
# FINISHED -- 999 iterations -- 0.008033s -- final value: nan -- final gradient norm: nan
# /home/tag/Desktop/M1AM/Optimization/TP/tp2/problem2.py:14: RuntimeWarning: overflow encountered in scalar power
#   g1 = 100*2*(x2 - x1**2)*(-2)*x1 -2*(1-x1)
# /home/tag/Desktop/M1AM/Optimization/TP/tp2/problem2.py:15: RuntimeWarning: overflow encountered in scalar power
#   g2 = 200*(x2 - x1**2)
# /home/tag/Desktop/M1AM/Optimization/TP/tp2/problem2.py:14: RuntimeWarning: invalid value encountered in scalar subtract
#   g1 = 100*2*(x2 - x1**2)*(-2)*x1 -2*(1-x1)
# /home/tag/Desktop/M1AM/Optimization/TP/tp2/problem2.py:15: RuntimeWarning: invalid value encountered in scalar subtract
#   g2 = 200*(x2 - x1**2)
# /home/tag/Desktop/M1AM/Optimization/TP/tp2/problem2.py:6: RuntimeWarning: overflow encountered in scalar power
#   return 100*(x[1] - x[0]**2)**2 + (1 - x[0])**2
# /home/tag/Desktop/M1AM/Optimization/TP/tp2/problem2.py:6: RuntimeWarning: invalid value encountered in scalar subtract
#   return 100*(x[1] - x[0]**2)**2 + (1 - x[0])**2
# /home/tag/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/ticker.py:2468: RuntimeWarning: overflow encountered in power
#   ticklocs = b ** decades
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/IPython/core/formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/backend_bases.py:2157, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2154     # we do this instead of `self.figure.draw_without_rendering`
#    2155     # so that we can inject the orientation
#    2156     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2157         self.figure.draw(renderer)
#    2158 if bbox_inches:
#    2159     if bbox_inches == "tight":
#
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/axes/_base.py:3226, in _AxesBase.draw(self, renderer)
#    3223 if artists_rasterized:
#    3224     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3226 mimage._draw_list_compositing_images(
#    3227     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3229 renderer.close_group('axes')
#    3230 self.stale = False
#
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/axis.py:1404, in Axis.draw(self, renderer)
#    1401     return
#    1402 renderer.open_group(__name__, gid=self.get_gid())
# -> 1404 ticks_to_draw = self._update_ticks()
#    1405 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1407 for tick in ticks_to_draw:
#
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/axis.py:1282, in Axis._update_ticks(self)
#    1277 """
#    1278 Update ticks (position and labels) using the current data interval of
#    1279 the axes.  Return the list of ticks that will be drawn.
#    1280 """
#    1281 major_locs = self.get_majorticklocs()
# -> 1282 major_labels = self.major.formatter.format_ticks(major_locs)
#    1283 major_ticks = self.get_major_ticks(len(major_locs))
#    1284 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/ticker.py:217, in Formatter.format_ticks(self, values)
#     215 """Return the tick labels for all the ticks at once."""
#     216 self.set_locs(values)
# --> 217 return [self(value, i) for i, value in enumerate(values)]
#
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/ticker.py:217, in <listcomp>(.0)
#     215 """Return the tick labels for all the ticks at once."""
#     216 self.set_locs(values)
# --> 217 return [self(value, i) for i, value in enumerate(values)]
#
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/ticker.py:1097, in LogFormatterMathtext.__call__(self, x, pos)
#    1095 # only label the decades
#    1096 fx = math.log(x) / math.log(b)
# -> 1097 is_x_decade = _is_close_to_int(fx)
#    1098 exponent = round(fx) if is_x_decade else np.floor(fx)
#    1099 coeff = round(b ** (fx - exponent))
#
# File ~/Desktop/M1AM/Optimization/TP/.venv/lib/python3.10/site-packages/matplotlib/ticker.py:2327, in _is_close_to_int(x)
#    2326 def _is_close_to_int(x):
# -> 2327     return math.isclose(x, round(x))
#
# OverflowError: cannot convert float infinity to integer
# From (-4,-4), the same step size diverges.

# %% [markdown]
# > Try to see if backtracking can help in minimizing the Rosenbrock function.

# %%
x_init = np.array([-4.0, -4.0])
x_star, x_tab = GD_backtracking(pb2.f, pb2.grad_f, x_init, 1.0, 0.5, 0.01, 1000, 1e-5)
plot_obj_normGrad(x_tab, pb2.f, pb2.grad_f, r"Backtracking GD on Rosenbrock with $x_0=(-4,-4)$")
print('Backtracking stabilizes the method and reaches the Rosenbrock valley.')
# Out:
# ------------------------------------
#  GD with backtracking line search
# ------------------------------------
# START
# FINISHED -- 51 iterations -- 0.002709s -- final value: 0.051075 -- final gradient norm: 0.408045
# Backtracking stabilizes the method and reaches the Rosenbrock valley.

# %% [markdown]
# ### Short answers
#
# - Among `0.1`, `0.3`, and `0.5`, the best fixed step on `f_1` is `0.3`: it converges in the fewest iterations.
# - With `tau = 0.51`, the method becomes unstable and diverges.
# - Backtracking makes the method much less sensitive to the initial guess `tau_0`; here `tau_0 = 10` is the fastest because the line-search quickly shrinks it to a good value.
# - For a quadratic function, the exact line-search step is `tau_k = ||g_k||^2 / <g_k, A g_k>`.
# - On the ill-conditioned problem `f_3`, tiny fixed steps are extremely slow, larger fixed steps diverge, and line-search methods remain stable but still suffer from the bad conditioning.
# - On the Rosenbrock function, a small fixed step such as `5e-3` works from `(0,0)` but not from `(-4,-4)`; backtracking helps because it adapts the step to the local geometry.
