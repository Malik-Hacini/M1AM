# %% [markdown]
# # Lab Session 2 : Introduction to Finite Differences schemes

# %% [markdown]
# In this lab we will investigate the Finite Difference (FD) method. This method belongs to one
# of the oldest ways of discretizing PDEs and is still used in a wide range of applications from
# climate and weather simulation to full waveform inversion for seismology.
